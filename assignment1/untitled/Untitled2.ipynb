# %%
import csv
lis=[]
with open('dataset_re.csv', newline='\n') as csvfile:
     spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
     for row in spamreader:
        lis.append(row)
        print(row)
# Out:
# ['ABED', ' 0']
# ['ABET', ' 1']
# ['ABID', ' 2']
# ['ABLE', ' 1']
# ['ABLY', ' 1']
# ['ABOS', ' 2']
# ['ABRI', ' 3']
# ['ABUT', ' 4']
# ['ABYE', ' 2']
# ['ABYS', ' 2']
# ['ACED', ' 3']
# ['ACER', ' 2']
# ['ACES', ' 3']
# ['ACHE', ' 1']
# ['ACHY', ' 1']
# ['ACID', ' 3']
# ['ACME', ' 2']
# ['ACNE', ' 3']
# ['ACRE', ' 4']
# ['ACTS', ' 2']
# ['ACYL', ' 2']
# ['ADIT', ' 2']
# ['ADOS', ' 3']
# ['ADRY', ' 4']
# ['ADZE', ' 1']
# ['AEON', ' 2']
# ['AERO', ' 3']
# ['AERY', ' 3']
# ['AESC', ' 2']
# ['AFRO', ' 2']
# ['AGED', ' 4']
# ['AGEN', ' 4']
# ['AGER', ' 4']
# ['AGES', ' 5']
# ['AGIN', ' 3']
# ['AGIO', ' 3']
# ['AGLU', ' 4']
# ['AGLY', ' 3']
# ['AGON', ' 3']
# ['AGUE', ' 2']
# ['AHED', ' 5']
# ['AHEM', ' 5']
# ['AHIS', ' 2']
# ['AHOY', ' 3']
# ['AIDE', ' 2']
# ['AIDS', ' 3']
# ['AILS', ' 4']
# ['AIMS', ' 5']
# ['AINE', ' 3']
# ['AINS', ' 4']
# ['AIRN', ' 4']
# ['AIRS', ' 5']
# ['AIRT', ' 6']
# ['AIRY', ' 4']
# ['AITS', ' 6']
# ['AITU', ' 5']
# ['AKED', ' 6']
# ['AKES', ' 6']
# ...

# %%
lis
# Out:
# [['ABED', ' 0'],
#  ['ABET', ' 1'],
#  ['ABID', ' 2'],
#  ['ABLE', ' 1'],
#  ['ABLY', ' 1'],
#  ['ABOS', ' 2'],
#  ['ABRI', ' 3'],
#  ['ABUT', ' 4'],
#  ['ABYE', ' 2'],
#  ['ABYS', ' 2'],
#  ['ACED', ' 3'],
#  ['ACER', ' 2'],
#  ['ACES', ' 3'],
#  ['ACHE', ' 1'],
#  ['ACHY', ' 1'],
#  ['ACID', ' 3'],
#  ['ACME', ' 2'],
#  ['ACNE', ' 3'],
#  ['ACRE', ' 4'],
#  ['ACTS', ' 2'],
#  ['ACYL', ' 2'],
#  ['ADIT', ' 2'],
#  ['ADOS', ' 3'],
#  ['ADRY', ' 4'],
#  ['ADZE', ' 1'],
#  ['AEON', ' 2'],
#  ['AERO', ' 3'],
#  ['AERY', ' 3'],
#  ['AESC', ' 2'],
#  ['AFRO', ' 2'],
#  ['AGED', ' 4'],
#  ['AGEN', ' 4'],
#  ['AGER', ' 4'],
#  ['AGES', ' 5'],
#  ['AGIN', ' 3'],
#  ['AGIO', ' 3'],
#  ['AGLU', ' 4'],
#  ['AGLY', ' 3'],
#  ['AGON', ' 3'],
#  ['AGUE', ' 2'],
#  ['AHED', ' 5'],
#  ['AHEM', ' 5'],
#  ['AHIS', ' 2'],
#  ['AHOY', ' 3'],
#  ['AIDE', ' 2'],
#  ['AIDS', ' 3'],
#  ['AILS', ' 4'],
#  ['AIMS', ' 5'],
#  ['AINE', ' 3'],
#  ['AINS', ' 4'],
#  ['AIRN', ' 4'],
#  ['AIRS', ' 5'],
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(lis[])
# Out:
#   File "<ipython-input-20-c776502c52c0>", line 2
#     plt.scatter(lis[])
#                     ^
# SyntaxError: invalid syntax

# %%
current list of hypotheses=total list
while the Current list of hypotheses is not empty do:

    choose hypothesis (A) that produces most branching
    for each hypothesis in current list do:
        separate hypothesis into sets based on predictions generated by comparing each hypothesis to selected hypothesis A. (Cats and Dogs)
        if an unseen prediction is encountered create a new set
    print the hypothesis A as output and receive prediction from adversary
    if prediction is “0C 4D”, all letters are in correct positions, return hypothesis A
    else current list of hypotheses= set of hypotheses with predictions that match the adversary
# Out:
#   File "<ipython-input-21-5601ed16641e>", line 1
#     current list of hypotheses=total list
#             ^
# SyntaxError: invalid syntax
